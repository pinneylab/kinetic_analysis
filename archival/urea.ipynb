# %%
urea = 3.000
buffer = 5.080

# %%
w = urea / (urea + buffer)

# %%
w
# Out:
# 0.3712871287128713

# %%
dd0 = 1 + 0.2658* w + 0.0330 * (w **2)

# %%
volume = (buffer+ urea) / dd0

# %%
urea / 60.056 / (volume / 1000)
# Out:
# 6.820597630945606
